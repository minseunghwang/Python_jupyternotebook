# %%
# 1. 사용자가 평가한 모든 영화의 전체 평균 평점을 출력하세요
import numpy as np
import pandas as pd

df = pd.read_csv("./data/movielens/ratings.csv")

print("전체 평균 평점 : {}".format(df["rating"].mean()))
# Out:
# 전체 평균 평점 : 3.501556983616962

# %%
# 2. 각 사용자별 평균 평점을 출력하세요
import numpy as np
import pandas as pd

df = pd.read_csv("./data/movielens/ratings.csv")
df2 = pd.read_csv("./data/movielens/movies.csv")

display((df.groupby("userId").mean()["rating"]).head())
display((df.groupby("userId").mean()["rating"]).tail())

# for i in range(1,int(data[:,0].max())+1):
#    # print("{0} 사용자 평균 평점 : {1}" .format(i, data[(data[:,0]==i)][0:600,2].mean()))
#     print("{0} 사용자 평균 평점 : {1:0.1f}" .format(i, data[(data[:,0]==i)][0:600,2].mean()))
# Out:
# userId
# 1    4.366379
# 2    3.948276
# 3    2.435897
# 4    3.555556
# 5    3.636364
# Name: rating, dtype: float64
# userId
# 606    3.657399
# 607    3.786096
# 608    3.134176
# 609    3.270270
# 610    3.688556
# Name: rating, dtype: float64

# %%
# 3. 각 영화별 평균 평점을 다음과 같은 형식으로 출력하세요!

import numpy as np
import pandas as pd

df = pd.read_csv("./data/movielens/ratings.csv")
df2 = pd.read_csv("./data/movielens/movies.csv")

df2.to_json("./data/movielens/movies.json")
df3=df2["title"]
display(type(df2["title"]))

# display(df3)

# df3 = pd.DataFrame(data1,index=[val for val in range(1,len(df)+1)])
df4 = pd.DataFrame(df3 ,index=[val for val in range(1,len(df3)+1)])

# df4=df.groupby("movieId").mean()["rating"]
# pd.merge(df3,df4,left_index=True, right_index=True, how="outer")
# display(df3)
display(df4)
# Out:
# pandas.core.series.Series
#                                                   title
# 1                                        Jumanji (1995)
# 2                               Grumpier Old Men (1995)
# 3                              Waiting to Exhale (1995)
# 4                    Father of the Bride Part II (1995)
# 5                                           Heat (1995)
# 6                                        Sabrina (1995)
# 7                                   Tom and Huck (1995)
# 8                                   Sudden Death (1995)
# 9                                      GoldenEye (1995)
# 10                       American President, The (1995)
# 11                   Dracula: Dead and Loving It (1995)
# 12                                         Balto (1995)
# 13                                         Nixon (1995)
# 14                              Cutthroat Island (1995)
# 15                                        Casino (1995)
# 16                         Sense and Sensibility (1995)
# 17                                    Four Rooms (1995)
# 18                Ace Ventura: When Nature Calls (1995)
# 19                                   Money Train (1995)
# 20                                    Get Shorty (1995)
# 21                                       Copycat (1995)
# 22                                     Assassins (1995)
# 23                                        Powder (1995)
# 24                             Leaving Las Vegas (1995)
# 25                                       Othello (1995)
# 26                                  Now and Then (1995)
# 27                                    Persuasion (1995)
# 28    City of Lost Children, The (Cité des enfants p...
# 29    Shanghai Triad (Yao a yao yao dao waipo qiao) ...
# 30                               Dangerous Minds (1995)
# ...                                                 ...
# 9713                        Ant-Man and the Wasp (2018)
# 9714                                      Dogman (2018)
# 9715                Mamma Mia: Here We Go Again! (2018)
# 9716                                         Tag (2018)
# 9717              The Man Who Killed Don Quixote (2018)
# 9718                                  Boundaries (2018)
# 9719                                      Spiral (2018)
# 9720               Mission: Impossible - Fallout (2018)
# 9721                                    SuperFly (2018)
# 9722                                Iron Soldier (2010)
# 9723                              BlacKkKlansman (2018)
# 9724                           The Darkest Minds (2018)
# 9725                                        Tilt (2011)
# 9726                 Jeff Ross Roasts the Border (2017)
# 9727                                   John From (2015)
# 9728                                Liquid Truth (2017)
# 9729                                       Bunny (1998)
# 9730  Hommage à Zgougou (et salut à Sabine Mamou) (2...
# 9731                                     Gintama (2017)
# 9732                          Gintama: The Movie (2010)
# 9733  anohana: The Flower We Saw That Day - The Movi...
# 9734                                Silver Spoon (2014)
# 9735            Love Live! The School Idol Movie (2015)
# 9736           Jon Stewart Has Left the Building (2015)
# 9737          Black Butler: Book of the Atlantic (2017)
# 9738                       No Game No Life: Zero (2017)
# 9739                                       Flint (2017)
# 9740                Bungo Stray Dogs: Dead Apple (2018)
# 9741                Andrew Dice Clay: Dice Rules (1991)
# 9742                                                NaN
#
# [9742 rows x 1 columns]

# %%
#.2 강사님
import numpy as np
import pandas as pd

result_df = pd.DataFrame(columns=["사용자별 평균평점"])
display(result_df)
# 사용자 id부터 뽑아내 보아요!
df = pd.read_csv("./data/movielens/ratings.csv")

display(df.head())
user_ids = df["userId"].unique()
user_ids.shape

for user_id in user_ids:
    # 각 유져별로 ratings를 추출
    user_mean=df.loc[df["userId"] == user_id ,"rating" ].mean()
    result_df.loc[user_id] = user_mean
display(result_df.head())
# Out:
# Empty DataFrame
# Columns: [사용자별 평균평점]
# Index: []
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
#    사용자별 평균평점
# 1   4.366379
# 2   3.948276
# 3   2.435897
# 4   3.555556
# 5   3.636364

# %%
## 이거

import numpy as np
import pandas as pd

result_df = pd.DataFrame(columns=["영화제목", "각 영화별 평균평점"])
# 사용자 id부터 뽑아내 보아요!
df = pd.read_csv("./data/movielens/ratings.csv")
df2 = pd.read_csv("./data/movielens/movies.csv")

df3=pd.merge(df2, df, on="movieId", how="right")
movie_ids = df3['movieId'].unique()

for movie_id in movie_ids:
    movie_mean=df3.loc[df3["movieId"] == movie_id ,"rating"].mean()
    movie_title=df3.loc[df3["movieId"] == movie_id ,"title"].min()
    result_df.loc[movie_id] = [movie_title, movie_mean]
display(result_df)
# Out:
#                                                      영화제목  각 영화별 평균평점
# 1                                        Toy Story (1995)    3.920930
# 2                                          Jumanji (1995)    3.431818
# 3                                 Grumpier Old Men (1995)    3.259615
# 4                                Waiting to Exhale (1995)    2.357143
# 5                      Father of the Bride Part II (1995)    3.071429
# 6                                             Heat (1995)    3.946078
# 7                                          Sabrina (1995)    3.185185
# 8                                     Tom and Huck (1995)    2.875000
# 9                                     Sudden Death (1995)    3.125000
# 10                                       GoldenEye (1995)    3.496212
# 11                         American President, The (1995)    3.671429
# 12                     Dracula: Dead and Loving It (1995)    2.421053
# 13                                           Balto (1995)    3.125000
# 14                                           Nixon (1995)    3.833333
# 15                                Cutthroat Island (1995)    3.000000
# 16                                          Casino (1995)    3.926829
# 17                           Sense and Sensibility (1995)    3.776119
# 18                                      Four Rooms (1995)    3.700000
# 19                  Ace Ventura: When Nature Calls (1995)    2.727273
# 20                                     Money Train (1995)    2.500000
# 21                                      Get Shorty (1995)    3.494382
# 22                                         Copycat (1995)    3.222222
# 23                                       Assassins (1995)    3.125000
# 24                                          Powder (1995)    3.125000
# 25                               Leaving Las Vegas (1995)    3.625000
# 26                                         Othello (1995)    3.500000
# 27                                    Now and Then (1995)    3.333333
# 28                                      Persuasion (1995)    4.227273
# 29      City of Lost Children, The (Cité des enfants p...    4.013158
# 30      Shanghai Triad (Yao a yao yao dao waipo qiao) ...    3.000000
# ...                                                   ...         ...
# 188189                         Sorry to Bother You (2018)    4.500000
# 188301                        Ant-Man and the Wasp (2018)    3.666667
# 188675                                      Dogman (2018)    3.500000
# 188751                Mamma Mia: Here We Go Again! (2018)    4.500000
# 188797                                         Tag (2018)    4.000000
# 188833              The Man Who Killed Don Quixote (2018)    4.500000
# 189043                                  Boundaries (2018)    2.500000
# 189111                                      Spiral (2018)    3.000000
# 189333               Mission: Impossible - Fallout (2018)    3.750000
# 189381                                    SuperFly (2018)    2.500000
# 189547                                Iron Soldier (2010)    1.000000
# 189713                              BlacKkKlansman (2018)    2.500000
# 190183                           The Darkest Minds (2018)    3.500000
# 190207                                        Tilt (2011)    1.500000
# 190209                 Jeff Ross Roasts the Border (2017)    4.000000
# 190213                                   John From (2015)    1.000000
# 190215                                Liquid Truth (2017)    1.500000
# 190219                                       Bunny (1998)    1.000000
# 190221  Hommage à Zgougou (et salut à Sabine Mamou) (2...    1.000000
# 191005                                     Gintama (2017)    4.500000
# 193565                          Gintama: The Movie (2010)    3.500000
# 193567  anohana: The Flower We Saw That Day - The Movi...    3.000000
# 193571                                Silver Spoon (2014)    4.000000
# 193573            Love Live! The School Idol Movie (2015)    4.000000
# 193579           Jon Stewart Has Left the Building (2015)    3.500000
# 193581          Black Butler: Book of the Atlantic (2017)    4.000000
# 193583                       No Game No Life: Zero (2017)    3.500000
# 193585                                       Flint (2017)    3.500000
# 193587                Bungo Stray Dogs: Dead Apple (2018)    3.500000
# 193609                Andrew Dice Clay: Dice Rules (1991)    4.000000
#
# [9724 rows x 2 columns]

# %%
## 3 번 스나버젼
'''
3. 각 영화별 평균 평점을 출력하세요.
'''
import numpy as np
import pandas as pd

df1 = pd.read_csv('./data/movielens/movies.csv')
df2 = pd.read_csv('./data/movielens/ratings.csv')

df3 = pd.merge(df1, df2, on='movieId', how='right')
#display(df3)

result_df = pd.DataFrame(columns=['영화제목','영화평점'])
#display(result_df)


movie_idx = df3['movieId'].unique()
print("=====" *2)


for val in movie_idx:
    movie_mean = df3.loc[ df3['movieId']==val ,'rating'].mean()
    movie_title = df3.loc[ df3['movieId']==val ,'title'].max()
#    result_df.loc[val]= [movie_mean,df3[val,'title']]
    result_df.loc[val]= [movie_title, movie_mean]
    


display(result_df)
# Out:
# ==========
#                                                      영화제목      영화평점
# 1                                        Toy Story (1995)  3.920930
# 2                                          Jumanji (1995)  3.431818
# 3                                 Grumpier Old Men (1995)  3.259615
# 4                                Waiting to Exhale (1995)  2.357143
# 5                      Father of the Bride Part II (1995)  3.071429
# 6                                             Heat (1995)  3.946078
# 7                                          Sabrina (1995)  3.185185
# 8                                     Tom and Huck (1995)  2.875000
# 9                                     Sudden Death (1995)  3.125000
# 10                                       GoldenEye (1995)  3.496212
# 11                         American President, The (1995)  3.671429
# 12                     Dracula: Dead and Loving It (1995)  2.421053
# 13                                           Balto (1995)  3.125000
# 14                                           Nixon (1995)  3.833333
# 15                                Cutthroat Island (1995)  3.000000
# 16                                          Casino (1995)  3.926829
# 17                           Sense and Sensibility (1995)  3.776119
# 18                                      Four Rooms (1995)  3.700000
# 19                  Ace Ventura: When Nature Calls (1995)  2.727273
# 20                                     Money Train (1995)  2.500000
# 21                                      Get Shorty (1995)  3.494382
# 22                                         Copycat (1995)  3.222222
# 23                                       Assassins (1995)  3.125000
# 24                                          Powder (1995)  3.125000
# 25                               Leaving Las Vegas (1995)  3.625000
# 26                                         Othello (1995)  3.500000
# 27                                    Now and Then (1995)  3.333333
# 28                                      Persuasion (1995)  4.227273
# 29      City of Lost Children, The (Cité des enfants p...  4.013158
# 30      Shanghai Triad (Yao a yao yao dao waipo qiao) ...  3.000000
# ...                                                   ...       ...
# 188189                         Sorry to Bother You (2018)  4.500000
# 188301                        Ant-Man and the Wasp (2018)  3.666667
# 188675                                      Dogman (2018)  3.500000
# 188751                Mamma Mia: Here We Go Again! (2018)  4.500000
# 188797                                         Tag (2018)  4.000000
# 188833              The Man Who Killed Don Quixote (2018)  4.500000
# 189043                                  Boundaries (2018)  2.500000
# 189111                                      Spiral (2018)  3.000000
# 189333               Mission: Impossible - Fallout (2018)  3.750000
# 189381                                    SuperFly (2018)  2.500000
# 189547                                Iron Soldier (2010)  1.000000
# 189713                              BlacKkKlansman (2018)  2.500000
# 190183                           The Darkest Minds (2018)  3.500000
# 190207                                        Tilt (2011)  1.500000
# 190209                 Jeff Ross Roasts the Border (2017)  4.000000
# 190213                                   John From (2015)  1.000000
# 190215                                Liquid Truth (2017)  1.500000
# 190219                                       Bunny (1998)  1.000000
# 190221  Hommage à Zgougou (et salut à Sabine Mamou) (2...  1.000000
# 191005                                     Gintama (2017)  4.500000
# 193565                          Gintama: The Movie (2010)  3.500000
# 193567  anohana: The Flower We Saw That Day - The Movi...  3.000000
# 193571                                Silver Spoon (2014)  4.000000
# 193573            Love Live! The School Idol Movie (2015)  4.000000
# 193579           Jon Stewart Has Left the Building (2015)  3.500000
# 193581          Black Butler: Book of the Atlantic (2017)  4.000000
# 193583                       No Game No Life: Zero (2017)  3.500000
# 193585                                       Flint (2017)  3.500000
# 193587                Bungo Stray Dogs: Dead Apple (2018)  3.500000
# 193609                Andrew Dice Clay: Dice Rules (1991)  4.000000
#
# [9724 rows x 2 columns]

# %%
# 4. 평균평점이 가장 높은 영화의 제목을 출력하세요
#     (동률이 있는 경우 모두 출력하세요)

res = pd.merge(df,result_df,left_on= "movieId",right_index=True,how= "inner")
# res = pd.merge(df_m,result2,left_on= "movieId",right_index=True,how= "inner")

tt = res.loc[res["각 영화별 평균평점"] == res["각 영화별 평균평점"].max()]
display(tt[["영화제목","각 영화별 평균평점"]])
# Out:
#                                                      영화제목  각 영화별 평균평점
# 260     The Jinx: The Life and Deaths of Robert Durst ...         5.0
# 290                       Galaxy of Terror (Quest) (1981)         5.0
# 294                            Alien Contamination (1980)         5.0
# 483                        I'm the One That I Want (2000)         5.0
# 8658                                  Lesson Faust (1994)         5.0
# 24700                                 Lesson Faust (1994)         5.0
# 8686                               Assignment, The (1997)         5.0
# 8698                                      Mephisto (1981)         5.0
# 9147                                         Black Mirror         5.0
# 9407                          Dylan Moran: Monster (2004)         5.0
# 9414                       Bill Hicks: Revelations (1993)         5.0
# 9921          My Sassy Girl (Yeopgijeogin geunyeo) (2001)         5.0
# 11462                              Strictly Sexual (2008)         5.0
# 12142      Story of Women (Affaire de femmes, Une) (1988)         5.0
# 12146       Passenger, The (Professione: reporter) (1975)         5.0
# 12152   Marriage of Maria Braun, The (Ehe der Maria Br...         5.0
# 13368                                     Lamerica (1994)         5.0
# 96115                                     Lamerica (1994)         5.0
# 13373   Entertaining Angels: The Dorothy Day Story (1996)         5.0
# 13680                                  Siam Sunset (1999)         5.0
# 13701                               Little Murders (1971)         5.0
# 13707                           Tales of Manhattan (1942)         5.0
# 13729                             Calcium Kid, The (2004)         5.0
# 13745           Go for Zucker! (Alles auf Zucker!) (2004)         5.0
# 13752                           Chump at Oxford, A (1940)         5.0
# 13762                   Ugly Duckling and Me!, The (2006)         5.0
# 13766                                   Breed, The (2006)         5.0
# 13767                      Sun Alley (Sonnenallee) (1999)         5.0
# 13769                     Valet, The (La doublure) (2006)         5.0
# 13780                      Watching the Detectives (2007)         5.0
# ...                                                   ...         ...
# 87219                           Monster Squad, The (1987)         5.0
# 87891   Match Factory Girl, The (Tulitikkutehtaan tytt...         5.0
# 88667                               Sandpiper, The (1965)         5.0
# 90034                                          61* (2001)         5.0
# 90238        Kung Fu Panda: Secrets of the Masters (2011)         5.0
# 91608                                    Knock Off (1998)         5.0
# 91974                                  Saving Face (2004)         5.0
# 92619                              One I Love, The (2014)         5.0
# 92620                                      Laggies (2014)         5.0
# 92621                                     Delirium (2014)         5.0
# 95789                           Unfaithfully Yours (1948)         5.0
# 96218   In the Realm of the Senses (Ai no corrida) (1976)         5.0
# 96434                                        Hype! (1996)         5.0
# 96445   Vampire in Venice (Nosferatu a Venezia) (Nosfe...         5.0
# 96530   Four Days in September (O Que É Isso, Companhe...         5.0
# 96673   Ballad of Narayama, The (Narayama bushiko) (1983)         5.0
# 96794                 Red Sorghum (Hong gao liang) (1987)         5.0
# 96869   Black Tar Heroin: The Dark End of the Street (...         5.0
# 96910                 All the Vermeers in New York (1990)         5.0
# 96935                  Vagabond (Sans toit ni loi) (1985)         5.0
# 96954                              Duel in the Sun (1946)         5.0
# 100075         Branded to Kill (Koroshi no rakuin) (1967)         5.0
# 100078          Last Hurrah for Chivalry (Hao xia) (1979)         5.0
# 100412             Love Exposure (Ai No Mukidashi) (2008)         5.0
# 100435                              Mother (Madeo) (2009)         5.0
# 100574                                 Holy Motors (2012)         5.0
# 100608                                Maniac Cop 2 (1990)         5.0
# 100667                      Only Lovers Left Alive (2013)         5.0
# 100722  Crippled Avengers (Can que) (Return of the 5 D...         5.0
# 100779                                 Tokyo Tribe (2014)         5.0
#
# [303 rows x 2 columns]

# %%
# 5. comdey영화 중 가장 평점이 낮은 영화의 제목을 출력하세요
#     (동률이 있는 경우 모두 출력하세요)

tttt=pd.merge(ttt,df2,how="right")
b_mask = tttt["genres"].str.contains("Comedy")
comedy_df = tttt.loc[b_mask,:]
ttttt = comedy_df.loc[comedy_df["각 영화별 평균평점"] == comedy_df["각 영화별 평균평점"].min() ]
display(ttttt[["영화제목","genres"]])

'''
b_mask = df2["genres"].str.contains("Comedy")
comedy_df = result.loc[b_mask,:]
min_ratings = comdey_df["영화평점"].min()
result = comedy.df.loc[comedy_df["영화평점"] == min_rating]
drop_result = result.drop("genres",axis=1,inplace=False)
display(drop_result.head())
display(drop_result.shape)
'''
# Out:
#                                                  영화제목  \
# 9                            Zombie Strippers! (2008)
# 10                            Follow Me, Boys! (1966)
# 13  Maria Bamford: The Special Special Special! (2...
# 14                          Haunted House 2, A (2014)
# 15                                 Bad Santa 2 (2016)
# 16                             The Emoji Movie (2017)
# 19                              Daddy Day Camp (2007)
# 20                                  Uncle Nino (2003)
# 22                       Brothers Solomon, The (2007)
# 24                                       Aloha (2015)
# 25                 Joe Dirt 2: Beautiful Loser (2015)
# 29                           Are We There Yet? (2005)
# 31         Carabineers, The (Carabiniers, Les) (1963)
# 33                       Hard Ticket to Hawaii (1987)
# 37                                    Old Dogs (2009)
# 56                              Secret Society (2002)
# 57               The Star Wars Holiday Special (1978)
# 58                            Saving Christmas (2014)
# 60                            Arthur Christmas (2011)
# 63  Boudu Saved From Drowning (Boudu sauvé des eau...
# 66            Journey 2: The Mysterious Island (2012)
# 69                               Tooth Fairy 2 (2012)
# 81                             Born to Be Wild (1995)
# 83                 Jesus Christ Vampire Hunter (2001)
# 84                      Leprechaun 4: In Space (1997)
#
#                                  genres
# 9                         Comedy|Horror
# 10                         Comedy|Drama
# 13                               Comedy
# 14                        Comedy|Horror
# 15                               Comedy
# 16            Animation|Children|Comedy
# 19                      Children|Comedy
# 20                               Comedy
# 22                               Comedy
# 24                 Comedy|Drama|Romance
# 25                               Comedy
# 29                      Children|Comedy
# 31                     Comedy|Drama|War
# 33                        Action|Comedy
# 37                               Comedy
# 56                               Comedy
# 57     Adventure|Children|Comedy|Sci-Fi
# 58                      Children|Comedy
# 60      Animation|Children|Comedy|Drama
# 63                               Comedy
# 66  Action|Adventure|Comedy|Sci-Fi|IMAX
# 69                      Children|Comedy
# 81      Adventure|Children|Comedy|Drama
# 83         Action|Comedy|Horror|Musical
# 84         Comedy|Fantasy|Horror|Sci-Fi
# '\nb_mask = df2["genres"].str.contains("Comedy")\ncomedy_df = result.loc[b_mask,:]\nmin_ratings = comdey_df["영화평점"].min()\nresult = comedy.df.loc[comedy_df["영화평점"] == min_rating]\ndrop_result = result.drop("genres",axis=1,inplace=False)\ndisplay(drop_result.head())\ndisplay(drop_result.shape)\n'

# %%
# 6. 2015년도에 평가된 모든 Romance영화의 평균 평점은?

from datetime import datetime
import time

# display(datetimeobj.year)

b_mask = tttt["genres"].str.contains("Romance")
comedy_df = tttt.loc[b_mask,:]
ttttt = comedy_df.loc

display(tttt)


d=datetime.fromtimestamp(time.time())
print(d)

# display(res)
# Out:
#       userId  movieId  rating     timestamp  \
# 0       10.0    97024     0.5  1.455302e+09
# 1       21.0    86068     0.5  1.418063e+09
# 2       21.0   107013     0.5  1.418063e+09
# 3       21.0   138186     0.5  1.436990e+09
# 4       21.0   160872     0.5  1.468114e+09
# 5       21.0   173307     0.5  1.500701e+09
# 6       51.0     5672     0.5  1.231041e+09
# 7      552.0     5672     0.5  1.111473e+09
# 8       51.0     6371     0.5  1.231041e+09
# 9       68.0    60363     0.5  1.240093e+09
# 10      88.0     7312     0.5  1.331421e+09
# 11      89.0     3604     0.5  1.520409e+09
# 12     103.0    77427     0.5  1.431956e+09
# 13     111.0   104644     0.5  1.517441e+09
# 14     111.0   110773     0.5  1.516156e+09
# 15     111.0   165645     0.5  1.516156e+09
# 16     184.0   175475     0.5  1.537110e+09
# 17     184.0   184641     0.5  1.537095e+09
# 18     204.0    83601     0.5  1.327183e+09
# 19     219.0    54768     0.5  1.194932e+09
# 20     221.0    31692     0.5  1.121365e+09
# 21     232.0    57326     0.5  1.241824e+09
# 22     298.0    54934     0.5  1.467490e+09
# 23     298.0    67799     0.5  1.450453e+09
# 24     298.0   134528     0.5  1.458650e+09
# 25     298.0   138798     0.5  1.450453e+09
# 26     307.0     4371     0.5  1.186086e+09
# 27     307.0     4750     0.5  1.186259e+09
# 28     307.0     7636     0.5  1.189608e+09
# 29     307.0    31422     0.5  1.186085e+09
# ...      ...      ...     ...           ...
# 9714     NaN   188189     NaN           NaN
# 9715     NaN   188301     NaN           NaN
# 9716     NaN   188675     NaN           NaN
# 9717     NaN   188751     NaN           NaN
# 9718     NaN   188797     NaN           NaN
# 9719     NaN   188833     NaN           NaN
# 9720     NaN   189043     NaN           NaN
# 9721     NaN   189111     NaN           NaN
# 9722     NaN   189333     NaN           NaN
# 9723     NaN   189381     NaN           NaN
# 9724     NaN   189547     NaN           NaN
# 9725     NaN   189713     NaN           NaN
# 9726     NaN   190183     NaN           NaN
# 9727     NaN   190207     NaN           NaN
# 9728     NaN   190209     NaN           NaN
# 9729     NaN   190213     NaN           NaN
# 9730     NaN   190215     NaN           NaN
# 9731     NaN   190219     NaN           NaN
# 9732     NaN   190221     NaN           NaN
# 9733     NaN   191005     NaN           NaN
# 9734     NaN   193565     NaN           NaN
# 9735     NaN   193567     NaN           NaN
# 9736     NaN   193571     NaN           NaN
# 9737     NaN   193573     NaN           NaN
# 9738     NaN   193579     NaN           NaN
# 9739     NaN   193581     NaN           NaN
# 9740     NaN   193583     NaN           NaN
# 9741     NaN   193585     NaN           NaN
# 9742     NaN   193587     NaN           NaN
# 9743     NaN   193609     NaN           NaN
#
#                                                    영화제목  각 영화별 평균평점  \
# 0             Rust and Bone (De rouille et d'os) (2012)         0.5
# 1     Films to Keep You Awake: The Christmas Tale (P...         0.5
# 2                             Christmas Carol, A (1977)         0.5
# 3                                         Sorrow (2015)         0.5
# 4                                        Satanic (2016)         0.5
# 5                        The Gracefield Incident (2015)         0.5
# 6     Pokemon 4 Ever (a.k.a. Pokémon 4: The Movie) (...         0.5
# 7     Pokemon 4 Ever (a.k.a. Pokémon 4: The Movie) (...         0.5
# 8                                 Pokémon Heroes (2003)         0.5
# 9                              Zombie Strippers! (2008)         0.5
# 10                              Follow Me, Boys! (1966)         0.5
# 11                                         Gypsy (1962)         0.5
# 12         Human Centipede, The (First Sequence) (2009)         0.5
# 13    Maria Bamford: The Special Special Special! (2...         0.5
# 14                            Haunted House 2, A (2014)         0.5
# 15                                   Bad Santa 2 (2016)         0.5
# 16                               The Emoji Movie (2017)         0.5
# 17                      Fullmetal Alchemist 2018 (2017)         0.5
# 18                                          Amer (2009)         0.5
# 19                                Daddy Day Camp (2007)         0.5
# 20                                    Uncle Nino (2003)         0.5
# 21    In the Name of the King: A Dungeon Siege Tale ...         0.5
# 22                         Brothers Solomon, The (2007)         0.5
# 23           The Butterfly Effect 3: Revelations (2009)         0.5
# 24                                         Aloha (2015)         0.5
# 25                   Joe Dirt 2: Beautiful Loser (2015)         0.5
# 26                                      Baby Boy (2001)         0.5
# 27                           3 Ninjas Knuckle Up (1995)         0.5
# 28                                  Raising Cain (1992)         0.5
# 29                             Are We There Yet? (2005)         0.5
# ...                                                 ...         ...
# 9714                                                NaN         NaN
# 9715                                                NaN         NaN
# 9716                                                NaN         NaN
# 9717                                                NaN         NaN
# 9718                                                NaN         NaN
# 9719                                                NaN         NaN
# 9720                                                NaN         NaN
# 9721                                                NaN         NaN
# 9722                                                NaN         NaN
# 9723                                                NaN         NaN
# 9724                                                NaN         NaN
# 9725                                                NaN         NaN
# 9726                                                NaN         NaN
# 9727                                                NaN         NaN
# 9728                                                NaN         NaN
# 9729                                                NaN         NaN
# 9730                                                NaN         NaN
# 9731                                                NaN         NaN
# 9732                                                NaN         NaN
# 9733                                                NaN         NaN
# 9734                                                NaN         NaN
# 9735                                                NaN         NaN
# 9736                                                NaN         NaN
# 9737                                                NaN         NaN
# 9738                                                NaN         NaN
# 9739                                                NaN         NaN
# 9740                                                NaN         NaN
# 9741                                                NaN         NaN
# 9742                                                NaN         NaN
# 9743                                                NaN         NaN
#
#                                                   title  \
# 0             Rust and Bone (De rouille et d'os) (2012)
# 1     Films to Keep You Awake: The Christmas Tale (P...
# 2                             Christmas Carol, A (1977)
# 3                                         Sorrow (2015)
# 4                                        Satanic (2016)
# 5                        The Gracefield Incident (2015)
# 6     Pokemon 4 Ever (a.k.a. Pokémon 4: The Movie) (...
# 7     Pokemon 4 Ever (a.k.a. Pokémon 4: The Movie) (...
# 8                                 Pokémon Heroes (2003)
# 9                              Zombie Strippers! (2008)
# 10                              Follow Me, Boys! (1966)
# 11                                         Gypsy (1962)
# 12         Human Centipede, The (First Sequence) (2009)
# 13    Maria Bamford: The Special Special Special! (2...
# 14                            Haunted House 2, A (2014)
# 15                                   Bad Santa 2 (2016)
# 16                               The Emoji Movie (2017)
# 17                      Fullmetal Alchemist 2018 (2017)
# 18                                          Amer (2009)
# 19                                Daddy Day Camp (2007)
# 20                                    Uncle Nino (2003)
# 21    In the Name of the King: A Dungeon Siege Tale ...
# 22                         Brothers Solomon, The (2007)
# 23           The Butterfly Effect 3: Revelations (2009)
# 24                                         Aloha (2015)
# 25                   Joe Dirt 2: Beautiful Loser (2015)
# 26                                      Baby Boy (2001)
# 27                           3 Ninjas Knuckle Up (1995)
# 28                                  Raising Cain (1992)
# 29                             Are We There Yet? (2005)
# ...                                                 ...
# 9714                         Sorry to Bother You (2018)
# 9715                        Ant-Man and the Wasp (2018)
# 9716                                      Dogman (2018)
# 9717                Mamma Mia: Here We Go Again! (2018)
# 9718                                         Tag (2018)
# 9719              The Man Who Killed Don Quixote (2018)
# 9720                                  Boundaries (2018)
# 9721                                      Spiral (2018)
# 9722               Mission: Impossible - Fallout (2018)
# 9723                                    SuperFly (2018)
# 9724                                Iron Soldier (2010)
# 9725                              BlacKkKlansman (2018)
# 9726                           The Darkest Minds (2018)
# 9727                                        Tilt (2011)
# 9728                 Jeff Ross Roasts the Border (2017)
# 9729                                   John From (2015)
# 9730                                Liquid Truth (2017)
# 9731                                       Bunny (1998)
# 9732  Hommage à Zgougou (et salut à Sabine Mamou) (2...
# 9733                                     Gintama (2017)
# 9734                          Gintama: The Movie (2010)
# 9735  anohana: The Flower We Saw That Day - The Movi...
# 9736                                Silver Spoon (2014)
# 9737            Love Live! The School Idol Movie (2015)
# 9738           Jon Stewart Has Left the Building (2015)
# 9739          Black Butler: Book of the Atlantic (2017)
# 9740                       No Game No Life: Zero (2017)
# 9741                                       Flint (2017)
# 9742                Bungo Stray Dogs: Dead Apple (2018)
# 9743                Andrew Dice Clay: Dice Rules (1991)
#
#                                       genres
# 0                              Drama|Romance
# 1                            Horror|Thriller
# 2                              Drama|Fantasy
# 3                         Crime|Drama|Horror
# 4                                     Horror
# 5                       Action|Horror|Sci-Fi
# 6       Adventure|Animation|Children|Fantasy
# 7       Adventure|Animation|Children|Fantasy
# 8                         Animation|Children
# 9                              Comedy|Horror
# 10                              Comedy|Drama
# 11                                   Musical
# 12                                    Horror
# 13                                    Comedy
# 14                             Comedy|Horror
# 15                                    Comedy
# 16                 Animation|Children|Comedy
# 17                  Action|Adventure|Fantasy
# 18                              Drama|Horror
# 19                           Children|Comedy
# 20                                    Comedy
# 21                  Action|Adventure|Fantasy
# 22                                    Comedy
# 23             Drama|Fantasy|Sci-Fi|Thriller
# 24                      Comedy|Drama|Romance
# 25                                    Comedy
# 26                               Crime|Drama
# 27                           Action|Children
# 28                           Horror|Thriller
# 29                           Children|Comedy
# ...                                      ...
# 9714                   Comedy|Fantasy|Sci-Fi
# 9715  Action|Adventure|Comedy|Fantasy|Sci-Fi
# 9716                             Crime|Drama
# 9717                          Comedy|Romance
# 9718                                  Comedy
# 9719                Adventure|Comedy|Fantasy
# 9720                            Comedy|Drama
# 9721                             Documentary
# 9722               Action|Adventure|Thriller
# 9723                   Action|Crime|Thriller
# 9724                           Action|Sci-Fi
# 9725                      Comedy|Crime|Drama
# 9726                         Sci-Fi|Thriller
# 9727                           Drama|Romance
# 9728                                  Comedy
# 9729                                   Drama
# 9730                                   Drama
# 9731                               Animation
# 9732                             Documentary
# 9733          Action|Adventure|Comedy|Sci-Fi
# 9734          Action|Animation|Comedy|Sci-Fi
# 9735                         Animation|Drama
# 9736                            Comedy|Drama
# 9737                               Animation
# 9738                             Documentary
# 9739         Action|Animation|Comedy|Fantasy
# 9740                Animation|Comedy|Fantasy
# 9741                                   Drama
# 9742                        Action|Animation
# 9743                                  Comedy
#
# [9744 rows x 8 columns]
# 2019-07-08 18:22:24.776372
